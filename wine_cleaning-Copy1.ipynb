# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
# nltk.download('punkt')
# nltk.download('stopwords')
stop = stopwords.words('english')

# %%
all_wines = pd.read_csv('Data/winemag-data-130k-v2.csv')
all_wines.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
clean_wines = all_wines.drop(columns=['Unnamed: 0', 'taster_twitter_handle', 'region_2'])
clean_wines = clean_wines.dropna()
clean_wines.head()
# Out:
#   country                                        description  \
# 3      US  Pineapple rind, lemon pith and orange blossom ...
# 4      US  Much like the regular bottling from 2012, this...
# 5   Spain  Blackberry and raspberry aromas show a typical...
# 6   Italy  Here's a bright, informal red that opens with ...
# 9  France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 9                         Les Natures      87   27.0             Alsace
#
#               region_1         taster_name  \
# 3  Lake Michigan Shore  Alexander Peartree
# 4    Willamette Valley        Paul Gregutt
# 5              Navarra   Michael Schachner
# 6             Vittoria       Kerin O’Keefe
# 9               Alsace          Roger Voss
#
#                                                title             variety  \
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
#
#                winery
# 3          St. Julian
# 4        Sweet Cheeks
# 5              Tandem
# 6     Terre di Giurfo
# 9  Jean-Baptiste Adam

# %%
clean_wines['variety'] = clean_wines['variety'].replace(['Weissburgunder'], 'Chardonnay')
clean_wines['variety'] = clean_wines['variety'].replace(['Spatburgunder'], 'Pinot Noir')
clean_wines['variety'] = clean_wines['variety'].replace(['Grauburgunder'], 'Pinot Gris')
clean_wines['variety'] = clean_wines['variety'].replace(['Garnacha'], 'Grenache')
clean_wines['variety'] = clean_wines['variety'].replace(['Pinot Nero'], 'Pinot Noir')
clean_wines['variety'] = clean_wines['variety'].replace(['Alvarinho'], 'Albarino')

# %%
clean_wines['vintage'] = clean_wines['title'].str.extract('(\d\d\d\d)', expand=True)
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage
# 3                    St. Julian    2013
# 4                  Sweet Cheeks    2012
# 5                        Tandem    2011
# 6               Terre di Giurfo    2013
# 9            Jean-Baptiste Adam    2012
# ...                         ...     ...
# 129959        Cave de Turckheim    2010
# 129962                 Cusumano    2012
# 129965  Domaine Rieflé-Landmann    2013
# 129968          Domaine Gresser    2013
# 129970         Domaine Schoffit    2012
#
# [54170 rows x 12 columns]

# %%
clean_wines['type'] = ['white' if x in ['Chardonnay', 'Riesling', 'Sauvignon Blanc', 'White Blend', 'Sparkling Blend', 'Pinot Gris',
                                        'Champagne Blend', 'GrÃ¼ner Veltliner', 'Pinot Grigio', 'Portuguese White', 'Viognier',
                                        'GewÃ¼rztraminer', 'GewÃ¼rztraminer'] else 'red' for x in clean_wines['variety']]
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage   type
# 3                    St. Julian    2013  white
# 4                  Sweet Cheeks    2012    red
# 5                        Tandem    2011    red
# 6               Terre di Giurfo    2013    red
# 9            Jean-Baptiste Adam    2012  white
# ...                         ...     ...    ...
# 129959        Cave de Turckheim    2010  white
# 129962                 Cusumano    2012    red
# 129965  Domaine Rieflé-Landmann    2013  white
# 129968          Domaine Gresser    2013    red
# 129970         Domaine Schoffit    2012    red
#
# [54170 rows x 13 columns]

# %%
clean_wines['word_count'] = clean_wines['description'].str.lower().str.split().str.len()
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage   type  word_count
# 3                    St. Julian    2013  white          33
# 4                  Sweet Cheeks    2012    red          41
# 5                        Tandem    2011    red          42
# 6               Terre di Giurfo    2013    red          31
# 9            Jean-Baptiste Adam    2012  white          30
# ...                         ...     ...    ...         ...
# 129959        Cave de Turckheim    2010  white          52
# 129962                 Cusumano    2012    red          37
# 129965  Domaine Rieflé-Landmann    2013  white          32
# 129968          Domaine Gresser    2013    red          43
# 129970         Domaine Schoffit    2012    red          27
#
# [54170 rows x 14 columns]

# %%
clean_wines = clean_wines[clean_wines['vintage'].notna()]
clean_wines = clean_wines.copy()
clean_wines['vintage'] = clean_wines['vintage'].astype(int)
clean_wines['age'] = 2020 - clean_wines['vintage'] 
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age
# 3                    St. Julian     2013  white          33    7
# 4                  Sweet Cheeks     2012    red          41    8
# 5                        Tandem     2011    red          42    9
# 6               Terre di Giurfo     2013    red          31    7
# 9            Jean-Baptiste Adam     2012  white          30    8
# ...                         ...      ...    ...         ...  ...
# 129959        Cave de Turckheim     2010  white          52   10
# 129962                 Cusumano     2012    red          37    8
# 129965  Domaine Rieflé-Landmann     2013  white          32    7
# 129968          Domaine Gresser     2013    red          43    7
# 129970         Domaine Schoffit     2012    red          27    8
#
# [51560 rows x 15 columns]

# %%
clean_wines = clean_wines.drop_duplicates('description')
clean_wines = clean_wines[pd.notnull(clean_wines.price)]

# %%
# clean_wines['winery_catalog'] = clean_wines['winery'].value_counts()
# clean_wines

# %%
# winery_counts = {}
# for row in clean_wines:
#     winery = clean_wines['winery']
        
#     try:
#         total_wines = winery_counts[winery] + 1
#         winery_counts[winery] = total_wines
        
#     except:
#         winery_counts[winery] = 1
# winery_counts
# # clean_wines['winery_catalog'] = 
# # clean_wines

# %%
clean_wines['word_count'].hist()
# Out:
# <AxesSubplot:>

# %%
clean_wines['points'].hist()
# Out:
# <AxesSubplot:>

# %%
clean_wines['great_meh'] = clean_wines['points'].apply(lambda x: 'great' if x >= 90 else 'meh')
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age great_meh
# 3                    St. Julian     2013  white          33    7       meh
# 4                  Sweet Cheeks     2012    red          41    8       meh
# 5                        Tandem     2011    red          42    9       meh
# 6               Terre di Giurfo     2013    red          31    7       meh
# 9            Jean-Baptiste Adam     2012  white          30    8       meh
# ...                         ...      ...    ...         ...  ...       ...
# 129959        Cave de Turckheim     2010  white          52   10     great
# 129962                 Cusumano     2012    red          37    8     great
# 129965  Domaine Rieflé-Landmann     2013  white          32    7     great
# 129968          Domaine Gresser     2013    red          43    7     great
# 129970         Domaine Schoffit     2012    red          27    8     great
#
# [47144 rows x 16 columns]

# %%
great_wines = clean_wines[clean_wines['great_meh'] == 'great']
great_wines
# Out:
#           country                                        description  \
# 123     Australia  The blend is roughly two-thirds Shiraz and one...
# 144            US  Thick and brooding, this dark, sweetly tannic ...
# 145            US  Cooked cranberry is spiced with anise, pepperc...
# 146            US  There's a touch of hot asphalt, pencil lead an...
# 147            US  Black cherry, black plum and black currant are...
# ...           ...                                                ...
# 129959     France  The granite soil of the Brand Grand Cru vineya...
# 129962      Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965     France  While it's rich, this beautiful dry wine also ...
# 129968     France  Well-drained gravel soil gives this wine its c...
# 129970     France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 123                     Parson's Flat      92   40.0    South Australia
# 144                           K Block      91   85.0         California
# 145                 Guidotti Vineyard      91   64.0         California
# 146                    Family Reserve      91   68.0         California
# 147                    Family Reserve      91   68.0         California
# ...                               ...     ...    ...                ...
# 129959                Brand Grand Cru      90   57.0             Alsace
# 129962      Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965    Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                          Kritt      90   30.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                         region_1     taster_name  \
# 123                    Padthaway  Joe Czerwinski
# 144     Spring Mountain District  Virginie Boone
# 145        Santa Lucia Highlands   Matt Kettmann
# 146            Santa Ynez Valley   Matt Kettmann
# 147            Santa Ynez Valley   Matt Kettmann
# ...                          ...             ...
# 129959                    Alsace      Roger Voss
# 129962                   Sicilia   Kerin O’Keefe
# 129965                    Alsace      Roger Voss
# 129968                    Alsace      Roger Voss
# 129970                    Alsace      Roger Voss
#
#                                                     title  \
# 123     Henry's Drive Vignerons 2006 Parson's Flat Shi...
# 144     Terra Valentine 2013 K Block Cabernet Sauvigno...
# 145     Testarossa 2013 Guidotti Vineyard Pinot Noir (...
# 146     Vincent Vineyards 2010 Family Reserve Cabernet...
# 147     Vincent Vineyards 2012 Family Reserve Cabernet...
# ...                                                   ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                           variety                   winery  vintage   type  \
# 123     Shiraz-Cabernet Sauvignon  Henry's Drive Vignerons     2006    red
# 144            Cabernet Sauvignon          Terra Valentine     2013    red
# 145                    Pinot Noir               Testarossa     2013    red
# 146            Cabernet Sauvignon        Vincent Vineyards     2010    red
# 147            Cabernet Sauvignon        Vincent Vineyards     2012    red
# ...                           ...                      ...      ...    ...
# 129959                 Pinot Gris        Cave de Turckheim     2010  white
# 129962               Nero d'Avola                 Cusumano     2012    red
# 129965                 Pinot Gris  Domaine Rieflé-Landmann     2013  white
# 129968             Gewürztraminer          Domaine Gresser     2013    red
# 129970             Gewürztraminer         Domaine Schoffit     2012    red
#
#         word_count  age great_meh
# 123             36   14     great
# 144             37    7     great
# 145             43    7     great
# 146             51   10     great
# 147             55    8     great
# ...            ...  ...       ...
# 129959          52   10     great
# 129962          37    8     great
# 129965          32    7     great
# 129968          43    7     great
# 129970          27    8     great
#
# [21520 rows x 16 columns]

# %%
features = clean_wines[['price', 'word_count', 'age']]
features
# Out:
#         price  word_count  age
# 3        13.0          33    7
# 4        65.0          41    8
# 5        15.0          42    9
# 6        16.0          31    7
# 9        27.0          30    8
# ...       ...         ...  ...
# 129959   57.0          52   10
# 129962   40.0          37    8
# 129965   28.0          32    7
# 129968   30.0          43    7
# 129970   21.0          27    8
#
# [47144 rows x 3 columns]

# %%
X = features
y = clean_wines['type']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=200, activation='relu', input_dim=3))
model.add(Dense(units=200, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=0
)

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11786/11786 - 1s - loss: 0.5238 - accuracy: 0.7777
# Normal Neural Network - Loss: 0.5238158954397519, Accuracy: 0.7777023315429688

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['red' 'red' 'red' 'red' 'red' 'red' 'red' 'red' 'red' 'red']
# Actual Labels: ['red', 'red', 'red', 'white', 'red', 'red', 'red', 'red', 'red', 'red']

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['meh' 'meh' 'meh' 'great' 'meh' 'great' 'meh' 'meh' 'great' 'great']
# Actual Labels: ['meh', 'meh', 'meh', 'great', 'meh', 'meh', 'meh', 'great', 'great', 'great']

# %%
X = clean_wines['word_count'].values.reshape(-1, 1)
y = clean_wines['points'].values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
plt.scatter(X, y)
# Out:
# Shape:  (47144, 1) (47144, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict(X_test)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 6.849243039591215
# R-squared (R2 ): 0.24762904580009515

# %%
model.score(X_test, y_test)
# Out:
# 0.24762904580009515

# %%
heatmap = sns.heatmap(clean_wines.corr(), annot=True, fmt=".2f")
sns.set(rc={'figure.figsize':(50, 30)})

# %%
X = clean_wines['word_count'].values.reshape(-1, 1)
y = clean_wines['price'].values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
plt.scatter(X, y)
# Out:
# Shape:  (47144, 1) (47144, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict(X_test)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 1205.8012295017452
# R-squared (R2 ): 0.06012925352568255

# %%
model.score(X_test, y_test)
# Out:
# 0.06012925352568255

# %%
clean_wines['tokenized_text'] = clean_wines['description'].apply(word_tokenize)
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age great_meh  \
# 3                    St. Julian     2013  white          33    7       meh
# 4                  Sweet Cheeks     2012    red          41    8       meh
# 5                        Tandem     2011    red          42    9       meh
# 6               Terre di Giurfo     2013    red          31    7       meh
# 9            Jean-Baptiste Adam     2012  white          30    8       meh
# ...                         ...      ...    ...         ...  ...       ...
# 129959        Cave de Turckheim     2010  white          52   10     great
# 129962                 Cusumano     2012    red          37    8     great
# 129965  Domaine Rieflé-Landmann     2013  white          32    7     great
# 129968          Domaine Gresser     2013    red          43    7     great
# 129970         Domaine Schoffit     2012    red          27    8     great
#
#                                            tokenized_text
# 3       [Pineapple, rind, ,, lemon, pith, and, orange,...
# 4       [Much, like, the, regular, bottling, from, 201...
# 5       [Blackberry, and, raspberry, aromas, show, a, ...
# 6       [Here, 's, a, bright, ,, informal, red, that, ...
# 9       [This, has, great, depth, of, flavor, with, it...
# ...                                                   ...
# 129959  [The, granite, soil, of, the, Brand, Grand, Cr...
# 129962  [Blackberry, ,, cassis, ,, grilled, herb, and,...
# 129965  [While, it, 's, rich, ,, this, beautiful, dry,...
# 129968  [Well-drained, gravel, soil, gives, this, wine...
# 129970  [Big, ,, rich, and, off-dry, ,, this, is, powe...
#
# [47144 rows x 17 columns]

# %%
clean_wines['tokenized_text'] = clean_wines['tokenized_text'].apply(lambda x: [w.lower() for w in x])

# %%
clean_wines['tokenized_text'] = clean_wines['tokenized_text'].apply(lambda x: [item for item in x if item not in stop])

# %%
clean_wines = clean_wines.reset_index(drop=True)
clean_wines
# Out:
#       country                                        description  \
# 0          US  Pineapple rind, lemon pith and orange blossom ...
# 1          US  Much like the regular bottling from 2012, this...
# 2       Spain  Blackberry and raspberry aromas show a typical...
# 3       Italy  Here's a bright, informal red that opens with ...
# 4      France  This has great depth of flavor with its fresh ...
# ...       ...                                                ...
# 47139  France  The granite soil of the Brand Grand Cru vineya...
# 47140   Italy  Blackberry, cassis, grilled herb and toasted a...
# 47141  France  While it's rich, this beautiful dry wine also ...
# 47142  France  Well-drained gravel soil gives this wine its c...
# 47143  France  Big, rich and off-dry, this is powered by inte...
#
#                               designation  points  price           province  \
# 0                    Reserve Late Harvest      87   13.0           Michigan
# 1      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 2                            Ars In Vitro      87   15.0     Northern Spain
# 3                                 Belsito      87   16.0  Sicily & Sardinia
# 4                             Les Natures      87   27.0             Alsace
# ...                                   ...     ...    ...                ...
# 47139                     Brand Grand Cru      90   57.0             Alsace
# 47140           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 47141         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 47142                               Kritt      90   30.0             Alsace
# 47143       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                   region_1         taster_name  \
# 0      Lake Michigan Shore  Alexander Peartree
# 1        Willamette Valley        Paul Gregutt
# 2                  Navarra   Michael Schachner
# 3                 Vittoria       Kerin O’Keefe
# 4                   Alsace          Roger Voss
# ...                    ...                 ...
# 47139               Alsace          Roger Voss
# 47140              Sicilia       Kerin O’Keefe
# 47141               Alsace          Roger Voss
# 47142               Alsace          Roger Voss
# 47143               Alsace          Roger Voss
#
#                                                    title             variety  \
# 0      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 1      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 2      Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 3       Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 4      Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                  ...                 ...
# 47139  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 47140  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 47141  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 47142  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 47143  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                         winery  vintage   type  word_count  age great_meh  \
# 0                   St. Julian     2013  white          33    7       meh
# 1                 Sweet Cheeks     2012    red          41    8       meh
# 2                       Tandem     2011    red          42    9       meh
# 3              Terre di Giurfo     2013    red          31    7       meh
# 4           Jean-Baptiste Adam     2012  white          30    8       meh
# ...                        ...      ...    ...         ...  ...       ...
# 47139        Cave de Turckheim     2010  white          52   10     great
# 47140                 Cusumano     2012    red          37    8     great
# 47141  Domaine Rieflé-Landmann     2013  white          32    7     great
# 47142          Domaine Gresser     2013    red          43    7     great
# 47143         Domaine Schoffit     2012    red          27    8     great
#
#                                           tokenized_text
# 0      [pineapple, rind, ,, lemon, pith, orange, blos...
# 1      [much, like, regular, bottling, 2012, ,, comes...
# 2      [blackberry, raspberry, aromas, show, typical,...
# 3      ['s, bright, ,, informal, red, opens, aromas, ...
# 4      [great, depth, flavor, fresh, apple, pear, fru...
# ...                                                  ...
# 47139  [granite, soil, brand, grand, cru, vineyard, p...
# 47140  [blackberry, ,, cassis, ,, grilled, herb, toas...
# 47141  ['s, rich, ,, beautiful, dry, wine, also, offe...
# 47142  [well-drained, gravel, soil, gives, wine, cris...
# 47143  [big, ,, rich, off-dry, ,, powered, intense, s...
#
# [47144 rows x 17 columns]

# %%
descriptors = pd.DataFrame(clean_wines.tokenized_text.values.tolist()).add_prefix('desc_')

# %%
descriptors = descriptors.reset_index(drop=True)

# %%
expanded_df = pd.merge(clean_wines, descriptors, left_index=True, right_index=True)
expanded_df
# Out:
#       country                                        description  \
# 0          US  Pineapple rind, lemon pith and orange blossom ...
# 1          US  Much like the regular bottling from 2012, this...
# 2       Spain  Blackberry and raspberry aromas show a typical...
# 3       Italy  Here's a bright, informal red that opens with ...
# 4      France  This has great depth of flavor with its fresh ...
# ...       ...                                                ...
# 47139  France  The granite soil of the Brand Grand Cru vineya...
# 47140   Italy  Blackberry, cassis, grilled herb and toasted a...
# 47141  France  While it's rich, this beautiful dry wine also ...
# 47142  France  Well-drained gravel soil gives this wine its c...
# 47143  France  Big, rich and off-dry, this is powered by inte...
#
#                               designation  points  price           province  \
# 0                    Reserve Late Harvest      87   13.0           Michigan
# 1      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 2                            Ars In Vitro      87   15.0     Northern Spain
# 3                                 Belsito      87   16.0  Sicily & Sardinia
# 4                             Les Natures      87   27.0             Alsace
# ...                                   ...     ...    ...                ...
# 47139                     Brand Grand Cru      90   57.0             Alsace
# 47140           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 47141         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 47142                               Kritt      90   30.0             Alsace
# 47143       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                   region_1         taster_name  \
# 0      Lake Michigan Shore  Alexander Peartree
# 1        Willamette Valley        Paul Gregutt
# 2                  Navarra   Michael Schachner
# 3                 Vittoria       Kerin O’Keefe
# 4                   Alsace          Roger Voss
# ...                    ...                 ...
# 47139               Alsace          Roger Voss
# 47140              Sicilia       Kerin O’Keefe
# 47141               Alsace          Roger Voss
# 47142               Alsace          Roger Voss
# 47143               Alsace          Roger Voss
#
#                                                    title             variety  \
# 0      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 1      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 2      Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 3       Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 4      Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                  ...                 ...
# 47139  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 47140  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 47141  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 47142  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 47143  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#        ... desc_74  desc_75 desc_76  desc_77  desc_78 desc_79 desc_80 desc_81  \
# 0      ...    None     None    None     None     None    None    None    None
# 1      ...    None     None    None     None     None    None    None    None
# 2      ...    None     None    None     None     None    None    None    None
# 3      ...    None     None    None     None     None    None    None    None
# 4      ...    None     None    None     None     None    None    None    None
# ...    ...     ...      ...     ...      ...      ...     ...     ...     ...
# 47139  ...    None     None    None     None     None    None    None    None
# 47140  ...    None     None    None     None     None    None    None    None
# 47141  ...    None     None    None     None     None    None    None    None
# 47142  ...    None     None    None     None     None    None    None    None
# 47143  ...    None     None    None     None     None    None    None    None
#
#       desc_82 desc_83
# 0        None    None
# 1        None    None
# 2        None    None
# 3        None    None
# 4        None    None
# ...       ...     ...
# 47139    None    None
# 47140    None    None
# 47141    None    None
# 47142    None    None
# 47143    None    None
#
# [47144 rows x 101 columns]

# %%
expanded_df = expanded_df.drop(columns=['tokenized_text', 'description'])
expanded_df
# Out:
#       country                         designation  points  price  \
# 0          US                Reserve Late Harvest      87   13.0
# 1          US  Vintner's Reserve Wild Child Block      87   65.0
# 2       Spain                        Ars In Vitro      87   15.0
# 3       Italy                             Belsito      87   16.0
# 4      France                         Les Natures      87   27.0
# ...       ...                                 ...     ...    ...
# 47139  France                     Brand Grand Cru      90   57.0
# 47140   Italy           Sàgana Tenuta San Giacomo      90   40.0
# 47141  France         Seppi Landmann Vallée Noble      90   28.0
# 47142  France                               Kritt      90   30.0
# 47143  France       Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                 province             region_1         taster_name  \
# 0               Michigan  Lake Michigan Shore  Alexander Peartree
# 1                 Oregon    Willamette Valley        Paul Gregutt
# 2         Northern Spain              Navarra   Michael Schachner
# 3      Sicily & Sardinia             Vittoria       Kerin O’Keefe
# 4                 Alsace               Alsace          Roger Voss
# ...                  ...                  ...                 ...
# 47139             Alsace               Alsace          Roger Voss
# 47140  Sicily & Sardinia              Sicilia       Kerin O’Keefe
# 47141             Alsace               Alsace          Roger Voss
# 47142             Alsace               Alsace          Roger Voss
# 47143             Alsace               Alsace          Roger Voss
#
#                                                    title             variety  \
# 0      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 1      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 2      Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 3       Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 4      Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                  ...                 ...
# 47139  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 47140  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 47141  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 47142  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 47143  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                         winery  ...  desc_74 desc_75  desc_76  desc_77  \
# 0                   St. Julian  ...     None    None     None     None
# 1                 Sweet Cheeks  ...     None    None     None     None
# 2                       Tandem  ...     None    None     None     None
# 3              Terre di Giurfo  ...     None    None     None     None
# 4           Jean-Baptiste Adam  ...     None    None     None     None
# ...                        ...  ...      ...     ...      ...      ...
# 47139        Cave de Turckheim  ...     None    None     None     None
# 47140                 Cusumano  ...     None    None     None     None
# 47141  Domaine Rieflé-Landmann  ...     None    None     None     None
# 47142          Domaine Gresser  ...     None    None     None     None
# 47143         Domaine Schoffit  ...     None    None     None     None
#
#       desc_78 desc_79 desc_80 desc_81 desc_82 desc_83
# 0        None    None    None    None    None    None
# 1        None    None    None    None    None    None
# 2        None    None    None    None    None    None
# 3        None    None    None    None    None    None
# 4        None    None    None    None    None    None
# ...       ...     ...     ...     ...     ...     ...
# 47139    None    None    None    None    None    None
# 47140    None    None    None    None    None    None
# 47141    None    None    None    None    None    None
# 47142    None    None    None    None    None    None
# 47143    None    None    None    None    None    None
#
# [47144 rows x 99 columns]

# %%
expanded_df = expanded_df.replace('['+string.punctuation+']', '', regex=True)
