# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# %%
all_wines = pd.read_csv('Data/winemag-data-130k-v2.csv')
all_wines.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
clean_wines = all_wines.drop(columns=['Unnamed: 0', 'taster_twitter_handle', 'region_2'])
clean_wines = clean_wines.dropna()
clean_wines.head()
# Out:
#   country                                        description  \
# 3      US  Pineapple rind, lemon pith and orange blossom ...
# 4      US  Much like the regular bottling from 2012, this...
# 5   Spain  Blackberry and raspberry aromas show a typical...
# 6   Italy  Here's a bright, informal red that opens with ...
# 9  France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 9                         Les Natures      87   27.0             Alsace
#
#               region_1         taster_name  \
# 3  Lake Michigan Shore  Alexander Peartree
# 4    Willamette Valley        Paul Gregutt
# 5              Navarra   Michael Schachner
# 6             Vittoria       Kerin O’Keefe
# 9               Alsace          Roger Voss
#
#                                                title             variety  \
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
#
#                winery
# 3          St. Julian
# 4        Sweet Cheeks
# 5              Tandem
# 6     Terre di Giurfo
# 9  Jean-Baptiste Adam

# %%
clean_wines['variety'] = clean_wines['variety'].replace(['Weissburgunder'], 'Chardonnay')
clean_wines['variety'] = clean_wines['variety'].replace(['Spatburgunder'], 'Pinot Noir')
clean_wines['variety'] = clean_wines['variety'].replace(['Grauburgunder'], 'Pinot Gris')
clean_wines['variety'] = clean_wines['variety'].replace(['Garnacha'], 'Grenache')
clean_wines['variety'] = clean_wines['variety'].replace(['Pinot Nero'], 'Pinot Noir')
clean_wines['variety'] = clean_wines['variety'].replace(['Alvarinho'], 'Albarino')

# %%
clean_wines['vintage'] = clean_wines['title'].str.extract('(\d\d\d\d)', expand=True)
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage
# 3                    St. Julian    2013
# 4                  Sweet Cheeks    2012
# 5                        Tandem    2011
# 6               Terre di Giurfo    2013
# 9            Jean-Baptiste Adam    2012
# ...                         ...     ...
# 129959        Cave de Turckheim    2010
# 129962                 Cusumano    2012
# 129965  Domaine Rieflé-Landmann    2013
# 129968          Domaine Gresser    2013
# 129970         Domaine Schoffit    2012
#
# [54170 rows x 12 columns]

# %%
clean_wines['type'] = ['white' if x in ['Chardonnay', 'Riesling', 'Sauvignon Blanc', 'White Blend', 'Sparkling Blend', 'Pinot Gris',
                                        'Champagne Blend', 'GrÃ¼ner Veltliner', 'Pinot Grigio', 'Portuguese White', 'Viognier',
                                        'GewÃ¼rztraminer', 'GewÃ¼rztraminer'] else 'red' for x in clean_wines['variety']]
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage   type
# 3                    St. Julian    2013  white
# 4                  Sweet Cheeks    2012    red
# 5                        Tandem    2011    red
# 6               Terre di Giurfo    2013    red
# 9            Jean-Baptiste Adam    2012  white
# ...                         ...     ...    ...
# 129959        Cave de Turckheim    2010  white
# 129962                 Cusumano    2012    red
# 129965  Domaine Rieflé-Landmann    2013  white
# 129968          Domaine Gresser    2013    red
# 129970         Domaine Schoffit    2012    red
#
# [54170 rows x 13 columns]

# %%
clean_wines['word_count'] = clean_wines['description'].str.lower().str.split().str.len()
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery vintage   type  word_count
# 3                    St. Julian    2013  white          33
# 4                  Sweet Cheeks    2012    red          41
# 5                        Tandem    2011    red          42
# 6               Terre di Giurfo    2013    red          31
# 9            Jean-Baptiste Adam    2012  white          30
# ...                         ...     ...    ...         ...
# 129959        Cave de Turckheim    2010  white          52
# 129962                 Cusumano    2012    red          37
# 129965  Domaine Rieflé-Landmann    2013  white          32
# 129968          Domaine Gresser    2013    red          43
# 129970         Domaine Schoffit    2012    red          27
#
# [54170 rows x 14 columns]

# %%
clean_wines = clean_wines[clean_wines['vintage'].notna()]
clean_wines = clean_wines.copy()
clean_wines['vintage'] = clean_wines['vintage'].astype(int)
clean_wines['age'] = 2020 - clean_wines['vintage'] 
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age
# 3                    St. Julian     2013  white          33    7
# 4                  Sweet Cheeks     2012    red          41    8
# 5                        Tandem     2011    red          42    9
# 6               Terre di Giurfo     2013    red          31    7
# 9            Jean-Baptiste Adam     2012  white          30    8
# ...                         ...      ...    ...         ...  ...
# 129959        Cave de Turckheim     2010  white          52   10
# 129962                 Cusumano     2012    red          37    8
# 129965  Domaine Rieflé-Landmann     2013  white          32    7
# 129968          Domaine Gresser     2013    red          43    7
# 129970         Domaine Schoffit     2012    red          27    8
#
# [51560 rows x 15 columns]

# %%
winery_counts = {}

clean_wines['winery_catalog'] = 
clean_wines
# Out:
#   File "<ipython-input-10-d4f678b63269>", line 3
#     clean_wines['winery_catalog'] =
#                                     ^
# SyntaxError: invalid syntax

# %%
clean_wines['word_count'].hist()
# Out:
# <AxesSubplot:>

# %%
X = clean_wines['word_count'].values.reshape(-1, 1)
y = clean_wines['points'].values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
plt.scatter(X, y)
# Out:
# Shape:  (51560, 1) (51560, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict(X_test)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 6.727288683510173
# R-squared (R2 ): 0.23768691959057797

# %%
model.score(X_test, y_test)
# Out:
# 0.23768691959057797

# %%
heatmap = sns.heatmap(clean_wines.corr(), annot=True, fmt=".2f")
sns.set(rc={'figure.figsize':(50, 30)})

# %%
X = clean_wines['word_count'].values.reshape(-1, 1)
y = clean_wines['price'].values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
plt.scatter(X, y)
# Out:
# Shape:  (51560, 1) (51560, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict(X_test)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 1159.4452190319842
# R-squared (R2 ): 0.053830657462457854

# %%
model.score(X_test, y_test)
# Out:
# 0.053830657462457854

# %% [markdown]
# Experiment 1 starts below. Working in PythonAdv, and I had to install seaborn and nltk, and I had to download nltk's "popular" datasets: python -m nltk.downloader popular

# %%
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age
# 3                    St. Julian     2013  white          33    7
# 4                  Sweet Cheeks     2012    red          41    8
# 5                        Tandem     2011    red          42    9
# 6               Terre di Giurfo     2013    red          31    7
# 9            Jean-Baptiste Adam     2012  white          30    8
# ...                         ...      ...    ...         ...  ...
# 129959        Cave de Turckheim     2010  white          52   10
# 129962                 Cusumano     2012    red          37    8
# 129965  Domaine Rieflé-Landmann     2013  white          32    7
# 129968          Domaine Gresser     2013    red          43    7
# 129970         Domaine Schoffit     2012    red          27    8
#
# [51560 rows x 15 columns]

# %%
clean_wines[clean_wines.duplicated('description',keep=False)].sort_values('description').head(5)
# Out:
#        country                                        description  \
# 72181       US  100% Sangiovese, this pale pink wine has notes...
# 119702      US  100% Sangiovese, this pale pink wine has notes...
# 77609       US  A 100% varietal wine fermented in stainless st...
# 55450       US  A 100% varietal wine fermented in stainless st...
# 17024       US  A 100% varietal wine from near the town of Gle...
#
#                    designation  points  price    province  \
# 72181                   Meadow      88   18.0  Washington
# 119702                  Meadow      88   18.0  Washington
# 77609   Woods Vineyard Rosé of      88   29.0  California
# 55450   Woods Vineyard Rosé of      88   29.0  California
# 17024             Estate Grown      90   32.0  California
#
#                     region_1       taster_name  \
# 72181   Columbia Valley (WA)  Sean P. Sullivan
# 119702  Columbia Valley (WA)  Sean P. Sullivan
# 77609   Russian River Valley    Virginie Boone
# 55450   Russian River Valley    Virginie Boone
# 17024          Sonoma Valley    Virginie Boone
#
#                                                     title     variety  \
# 72181   Ross Andrew 2013 Meadow Rosé (Columbia Valley ...        Rosé
# 119702  Ross Andrew 2013 Meadow Rosé (Columbia Valley ...        Rosé
# 77609   Ousterhout 2015 Woods Vineyard Rosé of Pinot N...  Pinot Noir
# 55450   Ousterhout 2015 Woods Vineyard Rosé of Pinot N...  Pinot Noir
# 17024   Dunbar 2013 Estate Grown Zinfandel (Sonoma Val...   Zinfandel
#
#              winery  vintage type  word_count  age
# 72181   Ross Andrew     2013  red          25    7
# 119702  Ross Andrew     2013  red          25    7
# 77609    Ousterhout     2015  red          42    5
# 55450    Ousterhout     2015  red          42    5
# 17024        Dunbar     2013  red          50    7

# %%
clean_wines = clean_wines.drop_duplicates('description')
clean_wines = clean_wines[pd.notnull(clean_wines.price)]
clean_wines.shape
# Out:
# (47144, 15)

# %%
clean_wines
# Out:
#        country                                        description  \
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# 6        Italy  Here's a bright, informal red that opens with ...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129959  France  The granite soil of the Brand Grand Cru vineya...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                             Ars In Vitro      87   15.0     Northern Spain
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 9                              Les Natures      87   27.0             Alsace
# ...                                    ...     ...    ...                ...
# 129959                     Brand Grand Cru      90   57.0             Alsace
# 129962           Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
# 129965         Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                               Kritt      90   30.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# 9                    Alsace          Roger Voss
# ...                     ...                 ...
# 129959               Alsace          Roger Voss
# 129962              Sicilia       Kerin O’Keefe
# 129965               Alsace          Roger Voss
# 129968               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# ...                                                   ...                 ...
# 129959  Cave de Turckheim 2010 Brand Grand Cru Pinot G...          Pinot Gris
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...        Nero d'Avola
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery  vintage   type  word_count  age
# 3                    St. Julian     2013  white          33    7
# 4                  Sweet Cheeks     2012    red          41    8
# 5                        Tandem     2011    red          42    9
# 6               Terre di Giurfo     2013    red          31    7
# 9            Jean-Baptiste Adam     2012  white          30    8
# ...                         ...      ...    ...         ...  ...
# 129959        Cave de Turckheim     2010  white          52   10
# 129962                 Cusumano     2012    red          37    8
# 129965  Domaine Rieflé-Landmann     2013  white          32    7
# 129968          Domaine Gresser     2013    red          43    7
# 129970         Domaine Schoffit     2012    red          27    8
#
# [47144 rows x 15 columns]

# %%
X = clean_wines.drop(['country','designation','points','province','region_1','variety','winery'], axis = 1)
y = clean_wines.variety

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (35358, 8) (11786, 8) (35358,) (11786,)

# %%
wine =clean_wines.variety.unique().tolist()
wine.sort()
wine[:10]
# Out:
# ['Abouriou',
#  'Aglianico',
#  'Airen',
#  'Albana',
#  'Albanello',
#  'Albariño',
#  'Aleatico',
#  'Alicante',
#  'Alicante Bouschet',
#  'Aligoté']

# %%
output = set()
for x in clean_wines.variety:
    x = x.lower()
    x = x.split()
    for y in x:
        output.add(y)

variety_list =sorted(output)
variety_list[:10]
# Out:
# ['abouriou',
#  'aglianico',
#  'airen',
#  'albana',
#  'albanello',
#  'albariño',
#  'aleatico',
#  'alejandría',
#  'alexandria',
#  'alicante']

# %%
import nltk

# %%
extras = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}', 'cab',"%"]
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
stop.update(variety_list)
stop.update(extras)

# %%
from scipy.sparse import hstack
from sklearn.feature_extraction.text import CountVectorizer 


vect = CountVectorizer(stop_words = stop)
X_train_dtm = vect.fit_transform(X_train.description)
price = X_train.price.values[:,None]
X_train_dtm = hstack((X_train_dtm, price))
X_train_dtm
# Out:
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\feature_extraction\text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['alexandrie', 'avola', 'bordeaux', 'cariñena', 'lo', 'merseguera', 'müller', 'oeil', 'rhône', 'semillon', 'style', 'thurgau', 'xarel'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# <35358x18014 sparse matrix of type '<class 'numpy.float64'>'
# 	with 908597 stored elements in COOrdinate format>

# %%
X_test_dtm = vect.transform(X_test.description)
price_test = X_test.price.values[:,None]
X_test_dtm = hstack((X_test_dtm, price_test))
X_test_dtm
# Out:
# <11786x18014 sparse matrix of type '<class 'numpy.float64'>'
# 	with 300712 stored elements in COOrdinate format>

# %%
from sklearn.linear_model import LogisticRegression
models = {}
for z in wine:
    model = LogisticRegression()
    y = y_train == z
    model.fit(X_train_dtm, y)
    models[z] = model

testing_probs = pd.DataFrame(columns = wine)
# Out:
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\potas\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-dd82c40a0814> in <module>
#       4     model = LogisticRegression()
#       5     y = y_train == z
# ----> 6     model.fit(X_train_dtm, y)
#       7     models[z] = model
#       8
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1372             raise ValueError("This solver needs samples of at least 2 classes"
#    1373                              " in the data, but the data contains only one"
# -> 1374                              " class: %r" % classes_[0])
#    1375
#    1376         if len(self.classes_) == 2:
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: False
